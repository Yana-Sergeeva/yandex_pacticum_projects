# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Фреймворк-ICE" data-toc-modified-id="Фреймворк-ICE-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Фреймворк ICE</a></span></li><li><span><a href="#Фреймворк-RICE" data-toc-modified-id="Фреймворк-RICE-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Фреймворк RICE</a></span></li><li><span><a href="#Таблица-orders" data-toc-modified-id="Таблица-orders-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Таблица orders</a></span></li><li><span><a href="#Таблица-visitors" data-toc-modified-id="Таблица-visitors-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Таблица visitors</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Анализ-А/В-теста" data-toc-modified-id="Анализ-А/В-теста-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ А/В-теста</a></span><ul class="toc-item"><li><span><a href="#График-кумулятивной-выручки-по-группам" data-toc-modified-id="График-кумулятивной-выручки-по-группам-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>График кумулятивной выручки по группам</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-В-к-группе-А" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-В-к-группе-А-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего чека группы В к группе А</a></span></li><li><span><a href="#График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам" data-toc-modified-id="График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>График кумулятивного среднего количества заказов на посетителя по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-В-к-группе-А" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-В-к-группе-А-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего количества заказов на посетителя группы В к группе А</a></span></li><li><span><a href="#Точечный-график-количества-заказов-по-пользователям" data-toc-modified-id="Точечный-график-количества-заказов-по-пользователям-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Точечный график количества заказов по пользователям</a></span></li><li><span><a href="#Подсчет-95-го-и-99-го-процентилей-количества-заказов-на-пользователя." data-toc-modified-id="Подсчет-95-го-и-99-го-процентилей-количества-заказов-на-пользователя.-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Подсчет 95-го и 99-го процентилей количества заказов на пользователя.</a></span></li><li><span><a href="#Точечный-график-стоимостей-заказов" data-toc-modified-id="Точечный-график-стоимостей-заказов-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Точечный график стоимостей заказов</a></span></li><li><span><a href="#Подсчет-95-го-и-99-го-процентилей" data-toc-modified-id="Подсчет-95-го-и-99-го-процентилей-7.9"><span class="toc-item-num">7.9&nbsp;&nbsp;</span>Подсчет 95-го и 99-го процентилей</a></span></li><li><span><a href="#График-кумулятивной-выручки-по-очищенным-данным" data-toc-modified-id="График-кумулятивной-выручки-по-очищенным-данным-7.10"><span class="toc-item-num">7.10&nbsp;&nbsp;</span>График кумулятивной выручки по очищенным данным</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам-по-очищенным-данным" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-по-очищенным-данным-7.11"><span class="toc-item-num">7.11&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам по очищенным данным</a></span></li><li><span><a href="#График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам-по-очищенным-данным" data-toc-modified-id="График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам-по-очищенным-данным-7.12"><span class="toc-item-num">7.12&nbsp;&nbsp;</span>График кумулятивного среднего количества заказов на посетителя по группам по очищенным данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-&quot;сырым&quot;-данным" data-toc-modified-id="Статистическая-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-&quot;сырым&quot;-данным-7.13"><span class="toc-item-num">7.13&nbsp;&nbsp;</span>Статистическая значимость различий в среднем количестве заказов на посетителя между группами по "сырым" данным</a></span></li><li><span><a href="#Статистическая-значимость-в-среднем-чеке-заказа-между-группами-по-&quot;сырым&quot;-данным" data-toc-modified-id="Статистическая-значимость-в-среднем-чеке-заказа-между-группами-по-&quot;сырым&quot;-данным-7.14"><span class="toc-item-num">7.14&nbsp;&nbsp;</span>Статистическая значимость в среднем чеке заказа между группами по "сырым" данным</a></span></li><li><span><a href="#Статистическя-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-&quot;очищенным&quot;-данным" data-toc-modified-id="Статистическя-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-&quot;очищенным&quot;-данным-7.15"><span class="toc-item-num">7.15&nbsp;&nbsp;</span>Статистическя значимость различий в среднем количестве заказов на посетителя между группами по "очищенным" данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-чеке-между-группами-по-&quot;очищенным&quot;-данным" data-toc-modified-id="Статистическая-значимость-различий-в-среднем-чеке-между-группами-по-&quot;очищенным&quot;-данным-7.16"><span class="toc-item-num">7.16&nbsp;&nbsp;</span>Статистическая значимость различий в среднем чеке между группами по "очищенным" данным</a></span></li><li><span><a href="#Итоги-исследования:" data-toc-modified-id="Итоги-исследования:-7.17"><span class="toc-item-num">7.17&nbsp;&nbsp;</span>Итоги исследования:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Проверка гипотез и результатов А/В-теста интернет-магазина для увеличения выручки

# %% [markdown]
# **Описание проекта**
#
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.
# Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.
#
# Данное исследование проводится с целью принятия одного из решений по результатам теста:
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.

# %% [markdown]
# # Описание проекта

# %% [markdown]
# **Часть 1. Приоритизация гипотез**
#
# В файле hypothesis.csv* 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами *Reach*, *Impact*, *Confidence*, *Effort*.
#
# Задача
#
# - Примените фреймворк *ICE* для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Примените фреймворк *RICE* для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Укажите, как изменилась приоритизация гипотез при применении *RICE* вместо *ICE*. Объясните, почему так произошло.

# %% [markdown]
# **Часть 2. Анализ A/B-теста**
#
# Вы провели A/B-тест и получили результаты, которые описаны в файлах /datasets/orders.csv и /datasets/visitors.csv.
#
# Задача
#
# Проанализируйте A/B-тест:
# - Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# - Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# - Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# - Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.
# - Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.
# - Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# - Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# - Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# - Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# - Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.
# - Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# - Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.
# - Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# - Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.

# %% [markdown]
# # Описание данных

# %% [markdown]
# **Данные для первой части**
#
# Файл `hypothesis.csv`
# - `Hypothesis` — краткое описание гипотезы;
# - `Reach` — охват пользователей по 10-балльной шкале;
# - `Impact` — влияние на пользователей по 10-балльной шкале;
# - `Confidence` — уверенность в гипотезе по 10-балльной шкале;
# - `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# **Данные для второй части**
#
# Файл `/orders.csv`
# - `transactionId` — идентификатор заказа;
# - `visitorId` — идентификатор пользователя, совершившего заказ;
# - `date` — дата, когда был совершён заказ;
# - `revenue` — выручка заказа;
# - `group` — группа A/B-теста, в которую попал заказ.
#
# Файл `visitors.csv`
# - `date` — дата;
# - `group` — группа A/B-теста;
# - `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %%
import pandas as pd
import scipy.stats as stats
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Часть 1. Приоритизация гипотез

# %% [markdown]
# ## Предобработка данных

# %%
# Загрузим датасет с гипотезами
df = pd.read_csv('hypothesis.csv', sep=',')
df
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
# 5           2        3
# 6           8        3
# 7           8        5
# 8           9        5

# %%
# Приведу названия столбцов к нижнему регистру
df.columns = df.columns.str.lower()

# %% [markdown]
# ## Фреймворк ICE

# %%
# Посчитаю ICE для гипотез
df['ICE'] = ((df['impact']*df['confidence'])/df['efforts']).round(1)
# Сделаю настройку, чтобы отображался весь столбец с описанием гипотез
pd.set_option('display.max_colwidth', 0)
df[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 8  Запустить акцию, дающую скидку на товар в день рождения
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#     ICE
# 8  16.2
# 0  13.3
# ...

# %% [markdown]
# Наиболее перспективные гипотезы по ICE 0, 7 и 8. На первом месте гипотеза под номером 8.

# %% [markdown]
# ## Фреймворк RICE

# %%
# Посчитаю RICE для гипотез
df['RICE'] = ((df['reach']*df['impact']*df['confidence'])/df['efforts']).round(1)
# Сделаю настройку, чтобы отображался весь столбец с описанием гипотез
pd.set_option('display.max_colwidth', 0)
df[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8  Запустить акцию, дающую скидку на товар в день рождения
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#     RICE
# 7  112.0
# ...

# %% [markdown]
# По параметру RICE наиболее перспективные гипотезы под номерами 0, 2, 6 и 7. На первом месте гипотеза под номером 7.

# %%
# Выведу одновременно результаты и RICE и ICE для удобства сравнения
df[['hypothesis', 'ICE', 'RICE']].sort_values(by='RICE', ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8  Запустить акцию, дающую скидку на товар в день рождения
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#     ICE   RICE
# ...

# %% [markdown]
# **Вывод**
#
# Гипотезы 0 и 7 перспективны по обоим параметрам.
#
# Гипотеза 8 перспективна только по параметру ICE, а гипотезы 0 и 6 по параметру RICE.
#
# Так получилось, потому что при подсчете параметра RICE учитывается количество пользователей, которых затронет изменение (reach). У гипотезы 7 reach равен 10, у остальных гипотез он меньше.

# %% [markdown]
# # Часть 2. Анализ А/В-теста

# %%
# Загружу таблицы с результатами проведенного А/В-теста
orders, visitors  = (
    pd.read_csv('orders.csv'),
    pd.read_csv('visitors.csv')
)

# %% [markdown]
# Посмотрю, что из себя представляют файлы и общую информацию о таблицах чтобы определить:
# - корректно ли названы столбцы
# - какие типы данных у объектов
# - количество пропусков.

# %%
# Создам функцию, чтобы применить ее ко всем таблицам
def table_description(table):
    print('Первые пять строк таблицы:')
    display(table.head())
    print('-'*50)
    print('Общая информация по таблице:')
    print()
    display(table.info())
    print('-'*50)
    print('Доля пропусков в таблице:')
    print()
    display(table.isna().sum())
    print('-'*50)
    print('Количество дубликатов в таблице:', table.duplicated().sum())

# %% [markdown]
# ## Таблица orders

# %%
# Общая информация по таблице orders
print('Таблица orders')
print()
table_description(orders)
# Out:
# Таблица orders
#
# Первые пять строк таблицы:
#    transactionId   visitorId        date  revenue group
# 0  3667963787     3312258926  2019-08-15  1650     B
# 1  2804400009     3642806036  2019-08-15  730      B
# 2  2961555356     4069496402  2019-08-15  400      A
# 3  3797467345     1196621759  2019-08-15  9759     B
# 4  2282983706     2322279887  2019-08-15  2308     B
# --------------------------------------------------
# Общая информация по таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
# ...

# %% [markdown]
# - **Пропусков и дубликатов нет.**
# - **Названия столбцов transactionId и visitorId приведу к змеиному регистру.**
# - **Тип данных столбца date изменю на datetime.**

# %%
# Изменю тип данных столбца date
orders['date'] = orders['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %%
# Выведу минимальные и максимальные даты в таблице
print('Дата начала покупок', orders['date'].min())
print('Дата окончания покупок', orders['date'].max())
# Out:
# Дата начала покупок 2019-08-01 00:00:00
# Дата окончания покупок 2019-08-31 00:00:00

# %% [markdown]
# Эксперимент проводился в течение августа 2019 г

# %%
# Изменю названия колонок
orders = orders.rename(
    columns={
        'transactionId':'transaction_id',
        'visitorId':'visitor_id'
    }
)

# %%
# Проверю, что все изменения прошли
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  1197 non-null   int64
#  1   visitor_id      1197 non-null   int64
#  2   date            1197 non-null   datetime64[ns]
#  3   revenue         1197 non-null   int64
#  4   group           1197 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB

# %%
# Посмотрю на количество групп в таблице
orders['group'].value_counts()
# Out:
# B    640
# A    557
# Name: group, dtype: int64

# %% [markdown]
# Групп всего 2. Предобработка данных таблицы orders завершена. Дальнейшая обработка не требуется.

# %% [markdown]
# ## Таблица visitors

# %%
# Общая информация по таблице visitors
print('Таблица visitors')
print()
table_description(visitors)
# Out:
# Таблица visitors
#
# Первые пять строк таблицы:
#          date group  visitors
# 0  2019-08-01  A     719
# 1  2019-08-02  A     619
# 2  2019-08-03  A     507
# 3  2019-08-04  A     717
# 4  2019-08-05  A     756
# --------------------------------------------------
# Общая информация по таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# None
# --------------------------------------------------
# Доля пропусков в таблице:
# date        0
# group       0
# visitors    0
# dtype: int64
# --------------------------------------------------
# Количество дубликатов в таблице: 0

# %% [markdown]
# **Пропусков и дубликатов в таблице visitors нет. Названия столбцов корректны. Необходимо изменить тип данных колонки date на datetime**

# %%
# Изменю тип данных столбца date
visitors['date'] = visitors['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %%
# Выведу минимальные и максимальные даты в таблице
print('Дата начала посещений', visitors['date'].min())
print('Дата окончания посещений', visitors['date'].max())
# Out:
# Дата начала посещений 2019-08-01 00:00:00
# Дата окончания посещений 2019-08-31 00:00:00

# %% [markdown]
# В таблице visitors тоже собраны даты за август 2019. Все в порядке.

# %%
# Проверю, что изменения прошли
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
#Посмотрю на количество групп в таблице
visitors['group'].value_counts()
# Out:
# A    31
# B    31
# Name: group, dtype: int64

# %% [markdown]
# В таблице visitors так же 2 группы. Предобработка таблицы visitors завершена.

# %% [markdown]
# **Вывод**
# - **В таблице orders изменены названия столбцов с учетом змеиного регистра. Столбец date приведен к типу данных datetime.**
# - **В таблице visitirs столбец date приведен к типу данных datetime.**
# - **В обеих таблицах данные по 2-м группам: А и В.**
# - **Данные в обеих таблицах за август 2019 года.**
#
# **Все готово к дальнейшему анализу.**

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# Для начала проверю, есть ли в таблице пользователи, которые попали в 2 группы одновременно.

# %%
# Создам переменную id пользователей в группе А
group_a = orders[orders['group'] == 'A']['visitor_id']
# Создам переменную id пользователей в группе B
group_b = orders[orders['group'] == 'B']['visitor_id']
# Сделаю срез таблицы orders , в котором id пользователей одновременно есть и в группе А и в группе В. 
#Вынесу его в отдельную переменную
id_ab = orders.query('visitor_id in @group_a and visitor_id in @group_b')

print('Количество пользователей одновременно в группе А и В:', id_ab['visitor_id'].nunique())
print('Количество пользователей, принимавших участие в эксперименте', orders['visitor_id'].nunique())
print('Доля пользователей в 2-х группах от общего количества пользователей', id_ab['visitor_id'].nunique()/ orders['visitor_id'].nunique()*100)
# Out:
# Количество пользователей одновременно в группе А и В: 58
# Количество пользователей, принимавших участие в эксперименте 1031
# Доля пользователей в 2-х группах от общего количества пользователей 5.625606207565471

# %% [markdown]
# Доля пользователей, попавших в обе группы одновременно составляет 5,63%. Это небольшой процент. Удалю этих пользователей для конкретного анализа проведенного А/В-теста

# %%
# Удаляю пользователей, попавших в обе группы теста
orders = orders.query('visitor_id not in @id_ab.visitor_id')
print('Количество пользователей для анализа А/В-теста:', orders['visitor_id'].nunique())
# Out:
# Количество пользователей для анализа А/В-теста: 973

# %% [markdown]
# ## Анализ А/В-теста

# %% [markdown]
# ### График кумулятивной выручки по группам

# %% [markdown]
# Пострю график кумулятивной выручки по группам в несколько шагов:
# - Создам массив уникальных пар значений дат и групп теста
# - Соберу агрегированные кумулятивные по дням данные о заказах
# - Соберу агрегированные кумулятивные по дням данные о посетителях интернет-магазина
# - Объединю кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
# - Построю графики кумулятивной выручки по дням и группам A/B-тестирования

# %%
# Создаю массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates()

# Получу агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# Получу агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# Объединю кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %% [markdown]
# Построю графики кумулятивной выручки по дням и группам A/B-тестирования:

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# Задаю размер фигуры
plt.figure(figsize=(15,6))
# График выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='Кум. выручка гр.A')

# График выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='Кум выручка гр.В')
plt.title('График кумулятивной выручки по группам')
plt.ylabel('Выручка')
plt.grid()
plt.legend()

# %% [markdown]
# Выручки обеих групп растут на прояжении всего периода теста.
#
# В период с 1 по 5 августа кум. выручки были примерно одинаковы. С 5 августа выручка группы В начинает расти активнее группы А, но 13 августа они опять сравниваются. После 13 августа выручка группы В опять растет быстрее. 18 августа заметен резкий скачок выручки группы В. Это может сигнализировать о всплесках числа заказов, либо о появлении очень дорогих заказов.

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %% [markdown]
# Построю графики среднего чека по группам — разделю кумулятивную выручку на кумулятивное число заказов:

# %%
plt.figure(figsize=(15,6))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='Кум. ср. чек гр.A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='Кум. ср. чек гр.B')

plt.title('График кумулятивного среднего чека по группам')
plt.ylabel('Средний чек')
plt.legend()
plt.grid()

# %% [markdown]
# В самом начале теста кум. средний чек группы А резко снижается, а группы В резко растет. Лишь 12.08 средний чек гр А становится немного выше, чем у группы В. Но уже 13.08 опять начинает падать и с эттой даты становиться равномерным. Уже 18.08 средние чеки обеих групп становятся равны.
# 19.08 средний чек группы В резко растет вверх и становится в 1,5 раза больше среднего чека группы А. Возможно в группу В попали крупные заказы. На следующий день средний чек группы В начинает снижаться и снижение происходит до конца месяца.  Группе В нужно больше данных, чтобы прийти к реальному среднему чеку и установиться на его уровне.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы В к группе А

# %% [markdown]
# Объединю таблицы cumulativeRevenueA и cumulativeRevenueB и построю график относительно различия кумулятивного среднего чека группы B к группе A.

# %%
# Объединю данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
# Строю отношение средних чеков
plt.figure(figsize=(15,6))
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)
plt.axhline(y=0, color='black', linestyle='--') 
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.grid()

# %% [markdown]
# В нескольких точках график различия между сегментами резко «скачет»

# %% [markdown]
# ### График кумулятивного среднего количества заказов на посетителя по группам

# %%
# считаю кумулятивное среднее количество заказов на посетителя
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяю данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяю данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строю графики
plt.figure(figsize=(15,6))
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='Кум. ср. кол-во заказов на посетителя группы А')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='Кум. ср. кол-во заказов на посетителя группы В')
plt.title('График кумулятивной среднего количества заказов по группам')
plt.ylabel('Кумулятивное среднее количество заказов на посетителя')
plt.grid()
plt.legend()

# %% [markdown]
# Количество заказов на посетителя группы А изначально было выше, чем группы В, через 2 дня после начала эксперимента количество заказов группы А начало резко снижаться и через 6 дней достигло уровня количество заказов группы В, после чего продолжило падение. К концу эксперимента количество заказов на посетителя круппы А стабилизировалось и осталось ниже среднего количества заказов на посетителя группы В.
#
# Среднее количество заказов на посетителя группы В с самого начала показало резкий рост, после этого в течении 2 дней показатели падали, но потом опять начался восходящий тренд. К концу эксперимента среднее количество заказов на посетителя выровнялась и стабильно остается выше среднего количества заказов на посетителя группы А.
#
# Можно сделать вывод, что Среднее количество заказов на посетителя группы В выше, чем Среднее количество заказов на посетителя у группы А

# %% [markdown]
# ### График относительного изменения кумулятивного среднего количества заказов на посетителя группы В к группе А

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(15,6))
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост среднего количества заказов группы B относительно группы A")
plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.16, color='grey', linestyle='--')
plt.title('График относительного изменения среднего количества заказов на посетителя группы B к группе A')
plt.grid()

# %% [markdown]
# Среднее количество заказов группы А до 06.08 была больше количества заказов группы В. Но после этой даты количество заказов группы В показывает себя примерно на 16% лучше, чем количество заказов группы А.

# %% [markdown]
# ### Точечный график количества заказов по пользователям

# %%
# Создаю таблицу с пользователями и количеством заказов на каждого пользователя
orders_by_users = (
    orders.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)

# Переименую колонки
orders_by_users.columns = ['visitor_id', 'orders']

print(orders_by_users.sort_values(by='orders', ascending=False).head(10))
# Out:
#      visitor_id  orders
# 908  3967698036  3
# 55   249864742   3
# 478  2108163459  3
# 687  2988190573  3
# 890  3908431265  3
# 138  611059232   3
# 632  2742574263  3
# 157  678354126   2
# 323  1404560065  2
# 452  1985475298  2

# %% [markdown]
# Максимальное количество заказов на одного пользователя - 3

# %%
x_values = pd.Series(range(0,len(orders_by_users)))

plt.figure(figsize=(15,6))
plt.scatter(x_values, orders_by_users['orders'], alpha=0.6) 
plt.title('Точечный график количества заказов по пользователям')
plt.xlabel('Число пользователей')
plt.ylabel('Количество заказов')
plt.grid()

# %% [markdown]
# Подавляющее число пользователей сделало 1 заказ. 2 и 3 заказа совершило гораздо меньше пользователей. Считать ли это выбросами пока не ясно. Посчитаю 95-й и 99-й процентили.

# %% [markdown]
# ### Подсчет 95-го и 99-го процентилей количества заказов на пользователя.

# %%
print(np.percentile(orders_by_users['orders'], [95, 99]))
# Out:
# [1. 2.]

# %% [markdown]
# 99% пользователей совершают не больше 2 заказов. Поэтому разумно считать, все значения больше 2-х аномальными.

# %% [markdown]
# ### Точечный график стоимостей заказов

# %%
x_values = pd.Series(range(0,len(orders['revenue'])))

plt.figure(figsize=(15,6))
plt.scatter(x_values, orders['revenue'], alpha=0.3)
plt.title('Точечный график стоимостей заказов')
plt.xlabel('Число заказов')
plt.ylabel('Стоимость заказов')
plt.grid()
plt.show()

# %% [markdown]
# Построю более наглядный график, исключив явные выбросы. Посторю граффик с суммами даказов не превышающие 200000.

# %%
x_values = pd.Series(range(0,len(orders['revenue'])))

plt.figure(figsize=(15,6))
plt.scatter(x_values, orders['revenue'], alpha=0.3)
plt.ylim(0, 200000)
plt.title('Точечный график стоимостей заказов')
plt.xlabel('Число заказов')
plt.ylabel('Стоимость заказов')
plt.grid()
plt.show()

# %% [markdown]
# В основном только недорогие заказов. Однако есть и дорогие заказы. Считать ли это выбросами пока не ясно. Посчитаю 95-й и 99-й процентили.

# %% [markdown]
# ### Подсчет 95-го и 99-го процентилей

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# Не больше 5% пользователей совершили покупку на сумму больше 27000 руб и не больше 1% - на сумму 54000. Поэтому разумно считать все заказа больше 54000 аномальными.

# %% [markdown]
# Построю графики по очищенным данным

# %% [markdown]
# Чтобы построить графики сначала отфильтрую таблицу orders по тем границам которые были установлены: сумма заказа не больше 54000 руб и количество заказов не больше 2-х

# %%
orders_filt = orders.copy()
# Мне нужны пользователи, которые сделали не больше 2-х заказов
orders_filt_user = (orders_filt
                    .groupby('visitor_id', as_index=False)
                    .agg({'transaction_id': pd.Series.nunique})
                    .query('transaction_id <= 2')
                   )
orders_filt = orders_filt.query('revenue <54000 and visitor_id in @orders_filt_user.visitor_id')

# %% [markdown]
# ### График кумулятивной выручки по очищенным данным

# %%
# Создаю массив уникальных пар значений дат и групп теста
datesGroups_filt = orders_filt[['date','group']].drop_duplicates()

# Получу агрегированные кумулятивные по дням данные о заказах 
ordersAggregated_filt = (datesGroups_filt
                         .apply(lambda x: orders_filt[np.logical_and(orders_filt['date'] <= x['date'], orders_filt['group'] == x['group'])]
                                .agg({'date' : 'max', 
                 'group' : 'max', 
                 'transaction_id' : 'nunique', 
                 'visitor_id' : 'nunique', 
                 'revenue' : 'sum'}), axis=1)
                         .sort_values(by=['date','group'])
                        )
# Получу агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = (datesGroups_filt
                           .apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])]
                                  .agg({'date' : 'max', 
                                        'group' : 'max',
                                        'visitors' : 'sum'}), axis=1)
                           .sort_values(by=['date','group'])
                          )

# Объединю кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData_filt = ordersAggregated_filt.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData_filt.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA_filt = cumulativeData_filt[cumulativeData_filt['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB_filt = cumulativeData_filt[cumulativeData_filt['group']=='B'][['date','revenue', 'orders']]

# Задаю размер фигуры
plt.figure(figsize=(15,6))
# График выручки группы А
plt.plot(cumulativeRevenueA_filt['date'], cumulativeRevenueA_filt['revenue'], label='Кум. выручка очищенных данных гр.A')

# График выручки группы B
plt.plot(cumulativeRevenueB_filt['date'], cumulativeRevenueB_filt['revenue'], label='Кум выручка очищенных данныхгр.В')
plt.title('График кумулятивной выручки по группам по очищенным данным')
plt.ylabel('Выручка')
plt.grid()
plt.legend()

# %% [markdown]
# **Вывод**
#
# По очищенным данным график кумулятивной выручки выглядит немного иначе. Первые 4 дня выручка одинакова и одинаково растет. Но начиная с 5 августа выручка группы В увеличилась и была больше на протяжении всего теста. Выручки обеих групп росли на протяжении всего эксперимента.

# %% [markdown]
# ### График кумулятивного среднего чека по группам по очищенным данным

# %%
plt.figure(figsize=(15,6))
plt.plot(cumulativeRevenueA_filt['date'], cumulativeRevenueA_filt['revenue']/cumulativeRevenueA_filt['orders'], label='Кум. ср. чек очищенных данных гр.A')
plt.plot(cumulativeRevenueB_filt['date'], cumulativeRevenueB_filt['revenue']/cumulativeRevenueB_filt['orders'], label='Кум. ср. чек очищенных данных гр.B')

plt.title('График кумулятивного среднего чека по очищенным данным по группам')
plt.ylabel('Средний чек')
plt.legend()
plt.grid()

# %% [markdown]
# График кумулятивного среднего чека после очищения данных так же изменился. После резкого падения среднего чека группы А и  резкого роста среднего чека группы В в начале эксперимента, уже к середине месяца их значения были почти одинаковы и стабилизировались.

# %% [markdown]
# ### График кумулятивного среднего количества заказов на посетителя по группам по очищенным данным

# %%
# считаю кумулятивное среднее количество заказов на посетителя
cumulativeData_filt['conversion'] = cumulativeData_filt['orders']/cumulativeData_filt['visitors']

# отделяю данные по группе A
cumulativeDataA_filt = cumulativeData_filt[cumulativeData_filt['group']=='A']

# отделяю данные по группе B
cumulativeDataB_filt = cumulativeData_filt[cumulativeData_filt['group']=='B']

# строю графики
plt.figure(figsize=(15,6))
plt.plot(cumulativeDataA_filt['date'], cumulativeDataA_filt['conversion'], label='Кум. ср. кол-во заказов на посетителя по очищенным данным группы А')
plt.plot(cumulativeDataB_filt['date'], cumulativeDataB_filt['conversion'], label='Кум. ср. кол-во заказов на посетителя по очищенным даннымгруппы В')
plt.title('График кумулятивной среднего количества заказов на посетителя по группам по очищенным данным')
plt.ylabel('Кумулятивное среднее количество заказов на посетителя')
plt.grid()
plt.legend()

# %% [markdown]
# График среднего количества заказов остался практически без изменений. Немного изменились лишь данные в начале эксперимента. Это и не удивительно, т.к. максимальное количество заказа на пользователя было 3 и таких заказов было всего 7. После их удаления они не могли существенно повлиять на картину.

# %% [markdown]
# ### Статистическая значимость различий в среднем количестве заказов на посетителя между группами по "сырым" данным

# %% [markdown]
# Сформулирую гипотезы.
#
# - H0: различий в среднем количестве заказов между группами нет.
# - H1: различия в среднем между группами есть.
#
# Порогом статистической значимости установим alpha = 0.05

# %%
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

# создаю переменные ordersByUsersA и ordersByUsersB со столбцами ['userId', 'orders'], 
# где для пользователей, совершивших хотя бы 1 заказ, будет указано число заказов. 
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['user_id', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['user_id', 'orders']

pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders')
[ordersByUsersA['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders')] 

# Объявлю переменные sampleA и sampleB, в которых пользователям с заказами будет соответствовать число заказов пользователя. 
# А пользователям без заказов — нули.
sampleA = pd.concat([ordersByUsersA['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders')],axis=0)

sampleB = pd.concat([ordersByUsersB['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])), name='orders')],axis=0)

# Применю критерий и отформатируем p-value, округлив его до трёх знаков после запятой.
# Выведем относительный прирост среднего числа заказов группы B.  Округлим до трёх знаков после запятой.
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['user_id', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['user_id', 'orders']

sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
alpha = 0.05
p_value = stats.mannwhitneyu(sampleA, sampleB)[1].round(5)
print('p-значение:', p_value)
if p_value < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
print('Относительный прирост среднего группы В к количеству заказов группы А: {0:.3f}'.format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-значение: 0.01102
# Отвергаем нулевую гипотезу
# Относительный прирост среднего группы В к количеству заказов группы А: 0.160

# %% [markdown]
# p-value меньше 0.05, поэтому отвергаем нулевую гипотезу (H0: различий в среднем количестве заказов между группами нет).
#
# В среднем количестве заказов между группамиесть статистически значимые различия. Относительный прирост среднего группы В к количеству заказов группы А равен 16%.

# %% [markdown]
# ### Статистическая значимость в среднем чеке заказа между группами по "сырым" данным

# %% [markdown]
# Сформулирую гипотезы:
# - H0: различий в среднем чеке между группами нет
# - H1: различия в среднем чеке между группами есть
#
# Порогом статистической значимости установим alpha = 0.05

# %%
alpha = 0.05
p_value = stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1].round(3)
print('p-значение:', p_value)
if p_value < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
print('Относительный прирост среднего чека группы В к группе А: {0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# p-значение: 0.829
# Не получилось отвергнуть нулевую гипотезу
# Относительный прирост среднего чека группы В к группе А: 0.287

# %% [markdown]
# p-value > 0.05, не получилось отвергнуть нулевую гипотезу. Однако, относительный прирост среднего чека группы В к группе А равен 28,7%. Это мы наблюдали на ранее выведенных графиках.

# %% [markdown]
# ### Статистическя значимость различий в среднем количестве заказов на посетителя между группами по "очищенным" данным

# %% [markdown]
# Сформулирую гипотезы:
# - H0: Среднее количество заказов на посетителя в группе A равна группе B
# - H1: Среднее количество заказов на посетителя в группе A не равна группе B
#
# Порогом статистической значимости установим alpha = 0.05

# %% [markdown]
# Приступаю к очищению данных от аномальных значений.
# Ранее пришла в выводу, что аномальные пользователи - те, кто совершил более 2 заказов или совершил заказ на сумму свыше 54000 рублей.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 2]['user_id'],
        ordersByUsersB[ordersByUsersB['orders'] > 2]['user_id'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > 54000]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
# Посчитаю количество аномальных пользователей
print(abnormalUsers.shape[0])
# Out:
# 16

# %% [markdown]
# Всего 16 аномальных пользователей. Посмотрю, как их действия повлияли на результаты теста. Посчитаю статистическую значимость различий в среднем количестве заказов между группами теста по очищенным данным. Сначала подготовлю выборки количества заказов по пользователям по группам теста:

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['user_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['user_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
# Применю статистический критерий Манна-Уитни к полученным выборкам:
alpha = 0.05
p_value = stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1].round(5)
print('p-значение:', p_value)
if p_value < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
print('Относительный прирост среднего группы В к количеству заказов группы А: {0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-значение: 0.00702
# Отвергаем нулевую гипотезу
# Относительный прирост среднего группы В к количеству заказов группы А: 0.189

# %% [markdown]
# p-value меньше 0.05, поэтому отвергаем нулевую гипотезу (H0: различий в среднем количестве заказов между группами нет) Среднее количество заказов на посетителя в группе A не равна группе B, т.е. между выборками имеется статистическая значимость.
#
# Относительный прирост среднего группы В к среднему количеству заказов группы А равен 18,9%. Это почти на 3% больше, чем при анализе по "сырым" данным.
# Подтвердилась та же гипотеза.

# %% [markdown]
# ### Статистическая значимость различий в среднем чеке между группами по "очищенным" данным

# %% [markdown]
# Сформулирую гипотезы:
# - H0: Средний чек в группе A равен группе B
# - H1: Средний чек в группе A не равен группе B
#
# Порогом статистической значимости установим alpha = 0.05

# %%
alpha = 0.05
p_value = stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1].round(3)
    
print('p-значение:', p_value)
if p_value < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
print('Относительный прирост среднего чека группы В к группе А: {0:.3f}'.format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# p-значение: 0.788
# Не получилось отвергнуть нулевую гипотезу
# Относительный прирост среднего чека группы В к группе А: -0.032

# %% [markdown]
# P-value намного больше значения 0.05, не получилось отвергнуть нулевую гипотезу. Средний чек в группе A равен группе B.
# Относительное снижение среднего чека группы В к группе А равно 3,2%. Разница с результатом по "сырым" данным составляет почти 30%.
# Подтвердилась та же гипотеза

# %% [markdown]
# ### Итоги исследования:
#
# По результатам проведенного А/В-тестирования было выявлено, что:
# - Различия в количестве заказов между группами А и В есть и по "сырым" и по "очищенным" данным. По сырым данным количество заказов группы В на 16% больше, чем у группы А, а по очищенным данным на 18,9%
# - Различий в среднем чеке между группами А и В нет. По сырым данным различие между средними чеками составляло 28,7%, но после удаления аномальных значений различие стало составлять лишь 2%
#
#
# Исходя из обнаруженных фактов, тест следует остановить и признать его успешным и сделать вывод, что средний чек обеих групп примерно равен, однако количество заказов группы В оказалась результативнее группы А.
